# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.python.keras import optimizers, losses, activations, models
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate, Flatten
from tensorflow.keras.metrics import AUC
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import train_test_split

# %%
df_1 = pd.read_csv("C:/00ETH/ml4h/Project1/archive/ptbdb_normal.csv", header=None)
df_2 = pd.read_csv("C:/00ETH/ml4h/Project1/archive/ptbdb_abnormal.csv", header=None)
df = pd.concat([df_1, df_2])

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1337, stratify=df[187])


Y = np.array(df_train[187].values).astype(np.int8)
X = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]

# %%
AUCROC = AUC(curve='ROC')
AUCPR = AUC(curve='PR')

# %%
def identity_block(x,filter):
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv1D(filter, kernel_size=5, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=1)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv1D(filter, kernel_size=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=1)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv1D(filter, kernel_size=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=1)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv1D(filter, kernel_size=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=1)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv1D(filter, kernel_size=3, padding = 'same')(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def get_model1():
    nclass = 1
    inp = Input(shape=(187, 1))
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(inp)
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(img_1)
    img_1 = tf.keras.layers.MaxPool1D(pool_size=2)(img_1)
    img_1 = tf.keras.layers.Dropout(rate=0.1)(img_1)
    
    img_2 = tf.keras.layers.Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_1)
    img_2 = tf.keras.layers.Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_1)
    img_2 = tf.keras.layers.MaxPool1D(pool_size=2)(img_1)
    img_2 = tf.keras.layers.Dropout(rate=0.1)(img_1)
    
    img_shortcut = identity_block(img_2,16)
    img_3 = tf.keras.layers.Conv1D(64, kernel_size=3, padding = 'same')(img_shortcut)
    img_3 = tf.keras.layers.Conv1D(64, kernel_size=3, padding = 'same')(img_3)
    img_1_3 = tf.keras.layers.Activation('relu')(img_3)
    
    img_4 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_1_3)
    img_4 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_1_3)
    img_4 = MaxPool1D(pool_size=2)(img_1_3)
    img_4 = Dropout(rate=0.1)(img_1)
    
    img_shortcut2 = convolutional_block(img_4,256)
    img_4 = tf.keras.layers.Conv1D(256, kernel_size=3, padding = 'same')(img_shortcut2)
    img_4 = tf.keras.layers.Conv1D(256, kernel_size=3, padding = 'same')(img_4)
    img_1_4 = tf.keras.layers.Activation('relu')(img_4)
    img_1_4 = GlobalMaxPool1D()(img_1_4)
    img_1_4 = Dropout(rate=0.2)(img_1_4)

    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_1")(img_1_4)
    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = tf.keras.layers.Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=[AUCROC, AUCPR, 'acc'])
    model.summary()
    return model

# %%
model1 = get_model1()
file_path = "Resnet_cnn_ptbdb1.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda\envs\ml4h\lib\site-packages\tensorflow\python\keras\metrics.py:1776: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 187, 1)]     0
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 187, 16)      96          input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 187, 16)      1296        conv1d_32[0][0]
# ...

# %%
model1.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model1.load_weights(file_path)

pred_test = model1.predict(X_test)
pred_test = (pred_test>0.5).astype(np.int8)
# Out:
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.69957, saving model to Resnet_cnn_ptbdb1.h5
# 10476/10476 - 20s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 2/1000
#
# Epoch 00002: val_acc did not improve from 0.69957
# 10476/10476 - 21s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 3/1000
#
# Epoch 00003: val_acc did not improve from 0.69957
# 10476/10476 - 21s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 4/1000
#
# Epoch 00004: val_acc did not improve from 0.69957
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ...

# %%
f1 = f1_score(Y_test, pred_test, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# Test f1 score : 0.4193097945342111
# Test accuracy score : 0.7220886293369976

# %%
def get_model2():
    nclass = 1
    inp = Input(shape=(187, 1))
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(inp)
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(img_1)
    img_1 = tf.keras.layers.MaxPool1D(pool_size=2)(img_1)
    img_1 = tf.keras.layers.Dropout(rate=0.1)(img_1)
    
    
    img_shortcut = identity_block(img_1,16)
    img_2 = tf.keras.layers.Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_shortcut)
    img_2 = tf.keras.layers.Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_shortcut)
    img_2 = tf.keras.layers.MaxPool1D(pool_size=2)(img_2)
    img_2 = tf.keras.layers.Dropout(rate=0.1)(img_2)
    
    img_shortcut2 = convolutional_block(img_2,32)
    img_3 = tf.keras.layers.Conv1D(64, kernel_size=3, padding = 'same')(img_shortcut2)
    img_3 = tf.keras.layers.Conv1D(64, kernel_size=3, padding = 'same')(img_3)
    img_1_3 = tf.keras.layers.Activation('relu')(img_3)
    
    img_shortcut3 = identity_block(img_1_3,64)
    img_4 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_shortcut3)
    img_4 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_shortcut3)
    img_4 = MaxPool1D(pool_size=2)(img_4)
    img_4 = Dropout(rate=0.1)(img_4)
    
    img_shortcut4 = convolutional_block(img_4,32)
    img_4 = tf.keras.layers.Conv1D(256, kernel_size=3, padding = 'same')(img_shortcut4)
    img_4 = tf.keras.layers.Conv1D(256, kernel_size=3, padding = 'same')(img_4)
    img_1_4 = tf.keras.layers.Activation('relu')(img_4)
    img_1_4 = GlobalMaxPool1D()(img_1_4)
    img_1_4 = Dropout(rate=0.2)(img_1_4)

    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_1")(img_1_4)
    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = tf.keras.layers.Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=[AUCROC,AUCPR, 'acc'])
    model.summary()
    return model

# %%
model2 = get_model2()
file_path = "Resnet_cnn_ptbdb2.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 187, 1)]     0
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 187, 16)      96          input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 187, 16)      1296        conv1d_47[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 93, 16)       0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 93, 16)       0           max_pooling1d_10[0][0]
# ...

# %%
model2.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model2.load_weights(file_path)

pred_test2 = model2.predict(X_test)
pred_test2 = (pred_test2>0.5).astype(np.int8)
# Out:
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.69957, saving model to Resnet_cnn_ptbdb2.h5
# 10476/10476 - 14s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 2/1000
#
# Epoch 00002: val_acc did not improve from 0.69957
# 10476/10476 - 9s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 3/1000
#
# Epoch 00003: val_acc did not improve from 0.69957
# 10476/10476 - 9s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 4/1000
#
# Epoch 00004: val_acc did not improve from 0.69957
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ...

# %%
f1 = f1_score(Y_test, pred_test2, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test2)

print("Test accuracy score : %s "% acc)
# Out:
# Test f1 score : 0.4193097945342111
# Test accuracy score : 0.7220886293369976

# %%
def get_model3():
    nclass = 1
    inp = Input(shape=(187, 1))
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(inp)
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(img_1)
    img_1 = tf.keras.layers.MaxPool1D(pool_size=2)(img_1)
    img_1 = tf.keras.layers.Dropout(rate=0.1)(img_1)
    
    
    img_shortcut = identity_block(img_1,16)
    img_shortcut2 = convolutional_block(img_shortcut,32)
    img_shortcut3 = identity_block(img_shortcut2,32)
    img_shortcut4 = convolutional_block(img_shortcut3,64)
    img_2 = tf.keras.layers.Activation('relu')(img_shortcut4)
   
    img_4 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_2)
    img_4 = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="same")(img_4)
    img_4 = MaxPool1D(pool_size=2)(img_4)
    img_4 = Dropout(rate=0.1)(img_1)
    
    img_shortcut5 = identity_block(img_4,16)
    img_shortcut6 = convolutional_block(img_shortcut5,256)
    img_4 = tf.keras.layers.Conv1D(256, kernel_size=3, padding = 'same')(img_shortcut6)
    img_4 = tf.keras.layers.Conv1D(256, kernel_size=3, padding = 'same')(img_4)
    img_1_4 = tf.keras.layers.Activation('relu')(img_4)
    img_1_4 = GlobalMaxPool1D()(img_1_4)
    img_1_4 = Dropout(rate=0.2)(img_1_4)

    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_1")(img_1_4)
    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = tf.keras.layers.Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=[AUCROC,AUCPR, 'acc'])
    model.summary()
    return model

# %%
model3 = get_model3()
file_path = "Resnet_cnn_ptbdb3.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            [(None, 187, 1)]     0
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 187, 16)      96          input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 187, 16)      1296        conv1d_76[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 93, 16)       0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 93, 16)       0           max_pooling1d_14[0][0]
# ...

# %%
model3.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model3.load_weights(file_path)

pred_test3 = model3.predict(X_test)
pred_test3 = (pred_test3>0.5).astype(np.int8)
# Out:
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.69957, saving model to Resnet_cnn_ptbdb3.h5
# 10476/10476 - 24s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 2/1000
#
# Epoch 00002: val_acc did not improve from 0.69957
# 10476/10476 - 22s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 3/1000
#
# Epoch 00003: val_acc did not improve from 0.69957
# 10476/10476 - 22s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 4/1000
#
# Epoch 00004: val_acc did not improve from 0.69957
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ...

# %%
f1 = f1_score(Y_test, pred_test3, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test3)

print("Test accuracy score : %s "% acc)
# Out:
# Test f1 score : 0.4193097945342111
# Test accuracy score : 0.7220886293369976

# %%
def get_model4():
    nclass = 1
    inp = Input(shape=(187, 1))
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(inp)
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(img_1)
    img_1 = tf.keras.layers.MaxPool1D(pool_size=2)(img_1)
    img_1 = tf.keras.layers.Dropout(rate=0.1)(img_1)
      
    img_shortcut = identity_block(img_1,16)
    img_shortcut2 = convolutional_block(img_shortcut,32)
    img_shortcut3 = identity_block(img_shortcut2,32)
    img_shortcut4 = convolutional_block(img_shortcut3,64)    
    img_shortcut5 = identity_block(img_shortcut4,64)
    img_shortcut6 = convolutional_block(img_shortcut5,256)
    img_2 = tf.keras.layers.Activation('relu')(img_shortcut6)
    
    
    img_3 = tf.keras.layers.Convolution1D(256, kernel_size=3, activation=activations.relu, padding="same")(img_2)
    img_3 = tf.keras.layers.Convolution1D(256, kernel_size=3, activation=activations.relu, padding="same")(img_3)
    img_3 = GlobalMaxPool1D()(img_3)
    img_3 = Dropout(rate=0.2)(img_3)

    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_1")(img_3)
    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = tf.keras.layers.Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=[AUCROC,AUCPR,'acc'])
    model.summary()
    return model

# %%
model4 = get_model4()
file_path = "Resnet_cnn_ptbdb4.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            [(None, 187, 1)]     0
# __________________________________________________________________________________________________
# conv1d_97 (Conv1D)              (None, 187, 16)      96          input_8[0][0]
# __________________________________________________________________________________________________
# conv1d_98 (Conv1D)              (None, 187, 16)      1296        conv1d_97[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 93, 16)       0           conv1d_98[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 93, 16)       0           max_pooling1d_16[0][0]
# ...

# %%
model4.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model4.load_weights(file_path)

pred_test4 = model4.predict(X_test)
pred_test4 = (pred_test4>0.5).astype(np.int8)
# Out:
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.69957, saving model to Resnet_cnn_ptbdb4.h5
# 10476/10476 - 48s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 2/1000
#
# Epoch 00002: val_acc did not improve from 0.69957
# 10476/10476 - 39s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 3/1000
#
# Epoch 00003: val_acc did not improve from 0.69957
# 10476/10476 - 41s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 4/1000
#
# Epoch 00004: val_acc did not improve from 0.69957
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ...

# %%
f1 = f1_score(Y_test, pred_test4, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test4)

print("Test accuracy score : %s "% acc)
# Out:
# Test f1 score : 0.4193097945342111
# Test accuracy score : 0.7220886293369976

# %%
def get_model5():
    nclass = 1
    inp = Input(shape=(187, 1))
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(inp)
    img_1 = tf.keras.layers.Convolution1D(16, kernel_size=5, activation=activations.relu, padding="same")(img_1)
    img_1 = tf.keras.layers.MaxPool1D(pool_size=2)(img_1)
    img_1 = tf.keras.layers.Dropout(rate=0.1)(img_1)
      
    img_shortcut = identity_block(img_1,16)
    img_shortcut2 = convolutional_block(img_shortcut,32)
    img_shortcut3 = identity_block(img_shortcut2,32)
    img_shortcut4 = convolutional_block(img_shortcut3,64) 
    img_shortcut5 = identity_block(img_shortcut4,64)
    img_shortcut6 = convolutional_block(img_shortcut5,256)
    img_2 = tf.keras.layers.Activation('relu')(img_shortcut6)
    
    
    img_3 = tf.keras.layers.Convolution1D(256, kernel_size=3, activation=activations.relu, padding="same")(img_2)
    img_3 = tf.keras.layers.Convolution1D(256, kernel_size=3, activation=activations.relu, padding="same")(img_3)
    img_3 = GlobalMaxPool1D()(img_3)
    img_3 = Dropout(rate=0.2)(img_3)

    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_1")(img_3)
    dense_1 = tf.keras.layers.Dense(64, activation=activations.relu, name="dense_2")(dense_1)
    dense_1 = tf.keras.layers.Dense(nclass, activation=activations.softmax, name="dense_3_mitbih")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=[AUCROC,AUCPR,'acc'])
    model.summary()
    return model

# %%
model5 = get_model5()
file_path = "Resnet_cnn_ptbdb5.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_9 (InputLayer)            [(None, 187, 1)]     0
# __________________________________________________________________________________________________
# conv1d_116 (Conv1D)             (None, 187, 16)      96          input_9[0][0]
# __________________________________________________________________________________________________
# conv1d_117 (Conv1D)             (None, 187, 16)      1296        conv1d_116[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 93, 16)       0           conv1d_117[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 93, 16)       0           max_pooling1d_17[0][0]
# ...

# %%
model5.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model5.load_weights(file_path)

pred_test5 = model5.predict(X_test)
pred_test5 = (pred_test5>0.5).astype(np.int8)
# Out:
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.69957, saving model to Resnet_cnn_ptbdb5.h5
# 10476/10476 - 54s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 2/1000
#
# Epoch 00002: val_acc did not improve from 0.69957
# 10476/10476 - 42s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 3/1000
#
# Epoch 00003: val_acc did not improve from 0.69957
# 10476/10476 - 44s - loss: 4.2256 - auc_4: 0.5000 - auc_5: 0.7244 - acc: 0.7244 - val_loss: 4.6066 - val_auc_4: 0.5000 - val_auc_5: 0.6996 - val_acc: 0.6996
# Epoch 4/1000
#
# Epoch 00004: val_acc did not improve from 0.69957
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ...

# %%
f1 = f1_score(Y_test, pred_test5, average="macro")

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test5)

print("Test accuracy score : %s "% acc)
# Out:
# Test f1 score : 0.4193097945342111
# Test accuracy score : 0.7220886293369976
